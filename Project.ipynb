# %%
import requests
import pandas as pd
import datetime
import pymysql
import sqlalchemy
import numpy as np
import keys
from keys import *

# %% [markdown]
# # Airport Arrivals

# %% [markdown]
# Find the Endpoint that contains the desired information to collect data about flight arrivals to an airport. If you need the IATA or ICAO codes of an airport, you can use an endpoint from this same API… or you can just Google it.
#
# Every day, the company wants to know which flights will arrive the next day. To automate this, you will have to come up with code that, when executed, generates tomorrow’s date and transforms it into the format that that particular API endpoint requires.
#
# If you feel like watching a video walkthrough about what APIs are and how to interact with them, you can hop on to the fourth chapter of this course:

# %%
url = "https://aerodatabox.p.rapidapi.com/airports/icao/EDDP"

headers = {
	"X-RapidAPI-Key": aerodatabox_key,
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)

response.json()
# Out:
# {"icao":"EDDP","iata":"LEJ","shortName":"Halle","fullName":"Leipzig, Leipzig Halle","municipalityName":"Leipzig","location":{"lat":51.4324,"lon":12.2416},"country":{"code":"DE","name":"Germany"},"continent":{"code":"EU","name":"Europe"},"timeZone":"Europe/Berlin","urls":{"webSite":"https://www.leipzig-halle-airport.de","wikipedia":"https://en.wikipedia.org/wiki/Leipzig/Halle_Airport","twitter":"http://twitter.com/lej_airport","googleMaps":"https://www.google.com/maps/@51.432399,12.241600,14z","flightRadar":"https://www.flightradar24.com/51.43,12.24/14"}}
# {'icao': 'EDDP',
#  'iata': 'LEJ',
#  'shortName': 'Halle',
#  'fullName': 'Leipzig, Leipzig Halle',
#  'municipalityName': 'Leipzig',
#  'location': {'lat': 51.4324, 'lon': 12.2416},
#  'country': {'code': 'DE', 'name': 'Germany'},
#  'continent': {'code': 'EU', 'name': 'Europe'},
#  'timeZone': 'Europe/Berlin',
#  'urls': {'webSite': 'https://www.leipzig-halle-airport.de',
#   'wikipedia': 'https://en.wikipedia.org/wiki/Leipzig/Halle_Airport',
#   'twitter': 'http://twitter.com/lej_airport',
#   'googleMaps': 'https://www.google.com/maps/@51.432399,12.241600,14z',
#   'flightRadar': 'https://www.flightradar24.com/51.43,12.24/14'}}

# %% [markdown]
# Generating tomorrow'sdate

# %%
tommorrow=datetime.date.today()+ datetime.timedelta(days=1)
tomrowstr=str(tommorrow)
tomrowstr
# Out:
# '2022-08-11'

# %% [markdown]
# Creating a function, that returns all flights departured on the next day from 8 am to 7pm at the chosen airport.Since IATA is not so commmonly used like, we use an additional API call to extract the needed ICAO Code for this airport.

# %%
def departured_flights8to12(iata):
    url_1 = "https://aerodatabox.p.rapidapi.com/airports/iata/"+iata+""

    headers = {
        "X-RapidAPI-Key": aerodatabox_key,
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    response_1 = requests.request("GET", url_1, headers=headers)    
    icaoc=response_1.json()["icao"]
    
    json_object=response_1.json()["icao"]
    
    url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/"+icaoc+"/"+tomrowstr+"T08:00/"+tomrowstr+"T12:00"

    querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

    headers = {
        "X-RapidAPI-Key": aerodatabox_key,
        "X-RapiddAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    data=response.json()["departures"]
    #print(response.text)
    flights=[]
    for i in data:
        flights_dic={}
        
        if "scheduledTimeLocal" in i["departure"].keys():
            flights_dic["Departure Local Time"]=i["departure"]["scheduledTimeLocal"]
        else:
            flights_dic["Departure Local Time"]="unknown"
            
    #    flights_dic["Departure Local Time"]=i["departure"]["scheduledTimeLocal"]
        
        if "scheduledTimeLocal" in i["arrival"].keys():
            flights_dic["Arriving at (Local Time)"]=i["arrival"]["scheduledTimeLocal"]
        else:
            flights_dic["Arriving at (Local Time)"]="unknown"
        #flights_dic["Arriving at (Local Time)"]=i["arrival"]["scheduledTimeLocal"]
        if "airport" in i["arrival"].keys():
            flights_dic["To"]=i["arrival"]["airport"]["name"]
        else:
            flights_dic["To"]="unknown" 
            
        if "number" in i.keys():
            flights_dic["Flight number"]=i["number"]
        else:
            flights_dic["Flight number"]="unknown"        
        if "name" in i["airline"].keys():
            flights_dic["Airline"]=i["airline"]["name"]
        else:
            flights_dic["Airline"]="unknown"         
        if "aircraft" in i.keys():
            flights_dic["Aircraft"]=i["aircraft"]["model"]
        else:
            flights_dic["Aircraft"]="unknown"

        #flights_dic["Aircraft"]=i["aircraft"]["model"]
        flights.append(flights_dic)
        df_flights=pd.DataFrame(flights)
    return df_flights
    #df_flights

# %%
departured_flights8to12("MUC")
# Out:
#        Departure Local Time Arriving at (Local Time)         To Flight number  \
# 0    2022-08-11 09:45+02:00                  unknown  Heraklion       4Y 1256
# 1    2022-08-11 10:20+02:00                  unknown    Antalya       XC 4104
# 2    2022-08-11 10:05+02:00                  unknown     Ankara       XC 5046
# 3    2022-08-11 11:50+02:00                  unknown    Toronto        AC 835
# 4    2022-08-11 11:00+02:00                  unknown      Arbil        UD 442
# ..                      ...                      ...        ...           ...
# 131  2022-08-11 10:25+02:00   2022-08-11 14:10+03:00     Bodrum       XC 6944
# 132  2022-08-11 10:50+02:00   2022-08-11 14:30+03:00   Istanbul       TK 1630
# 133  2022-08-11 11:00+02:00   2022-08-11 16:15+03:00      Arbil       W2 2242
# 134  2022-08-11 09:40+02:00   2022-08-11 16:20+03:00       Doha         QR 60
# 135  2022-08-11 10:55+02:00   2022-08-11 12:25+02:00   Belgrade       LH 1734
#
#                             Airline          Aircraft
# 0    Airbus Transport International           unknown
# 1                      Corendon Air       Airbus A320
# 2                      Corendon Air           unknown
# 3                        Air Canada  Boeing 777-200LR
# 4                                UR           unknown
# ..                              ...               ...
# 131                    Corendon Air       Airbus A320
# 132                         Turkish   Airbus A330-200
# 133                      FlexFlight       Airbus A320
# 134                   Qatar Airways      Boeing 787-8
# 135                       Lufthansa       Airbus A320
#
# [136 rows x 6 columns]

# %% [markdown]
# Based on information how the data is structured, we build a function, that provides us all arriving flights from 8 am to 7pm.

# %%
def arflights8to19(iata):
    
    url_1 = "https://aerodatabox.p.rapidapi.com/airports/iata/"+iata+""

    headers = {
        "X-RapidAPI-Key": aerodatabox_key,
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    response_1 = requests.request("GET", url_1, headers=headers)    
    icaoc=response_1.json()["icao"]
    
    json_object=response_1.json()["icao"]
    
    url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/"+icaoc+"/"+tomrowstr+"T08:00/"+tomrowstr+"T19:00"

    querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

    headers = {
        "X-RapidAPI-Key": aerodatabox_key,
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    data=response.json()["arrivals"]
    #print(response.text)
    flights=[]
    
    for i in data:
        flights_dic={}
        if "airport" in i["departure"].keys():#departure from
            flights_dic["departure_from"]=i["departure"]["airport"]["name"] 
        else:
            flights_dic["departure_from"]="unknown"
        if "scheduledTimeLocal" in i["departure"].keys():
            flights_dic["departure_time"]=i["departure"]["scheduledTimeLocal"]#departure time local
        else:
            flights_dic["departure_time"]="unknown"
            
        if "scheduledTimeLocal" in i["arrival"].keys():
            flights_dic["arrival_time"]=i["arrival"]["scheduledTimeLocal"]#arrival time local
        else:
            flights_dic["arrival_time"]="unknown"
            
        if "number" in i.keys():
            flights_dic["flight_number"]=i["number"] #flight number
        else:
            flights_dic["flight_number"]="unknown"
            
        if "terminal" in i["arrival"].keys():#departure from
            flights_dic["terminal"]=i["arrival"]["terminal"]
        else:
            flights_dic["terminal"]="unknown"
            
        if "airline" in i.keys():
            flights_dic["airline"]=i["airline"]["name"] #airline
        else:
            flights_dic["airline"]="unknown"
            
        if "aircraft" in i.keys(): #aicraft
            flights_dic["aircraft"]=i["aircraft"]["model"]
        else:
            flights_dic["aircraft"]="unknown"
        if "icao" in i["departure"]["airport"].keys():
            flights_dic["ICAO"]=i["departure"]["airport"]["icao"]  #icao
        else:
            flights_dic["ICAO"]="unknown"            

        if "iata" in i["departure"]["airport"].keys():
            flights_dic["IATA"]=i["departure"]["airport"]["iata"] #iata
        else:
            flights_dic["IATA"]="unknown"           

        flights.append(flights_dic)
        df_flights=pd.DataFrame(flights)
        df_flights["departure_time"]=df_flights["departure_time"].str.extract("(\d\d\d\d-\d\d-\d\d \d\d:\d\d)")
        df_flights["arrival_time"]=df_flights["arrival_time"].str.extract("(\d\d\d\d-\d\d-\d\d \d\d:\d\d)")
        df_flights["departure_time"]=pd.to_datetime(df_flights["departure_time"])
        df_flights["arrival_time"]=pd.to_datetime(df_flights["arrival_time"])
        df_flights = df_flights[df_flights["ICAO"] != "unknown"]
    return df_flights

# %%
df_arrivals=arflights8to19("BER")
df_arrivals
# Out:
#      departure_from      departure_time        arrival_time flight_number  \
# 0          Helsinki 2022-08-11 07:25:00 2022-08-11 08:25:00       AY 1431
# 1              Riga 2022-08-11 07:45:00 2022-08-11 08:20:00        BT 211
# 2              Oslo 2022-08-11 07:00:00 2022-08-11 08:35:00       DY 1100
# 3          Budapest 2022-08-11 06:55:00 2022-08-11 08:25:00        FR 197
# 4           Treviso 2022-08-11 07:10:00 2022-08-11 08:40:00       FR 2607
# ..              ...                 ...                 ...           ...
# 137         Antalya 2022-08-11 15:25:00 2022-08-11 18:00:00       PC 5007
# 138        Istanbul 2022-08-11 16:40:00 2022-08-11 18:40:00        PC 983
# 139  Kerkyra Island 2022-08-11 16:40:00 2022-08-11 18:00:00       U2 4732
# 140           Milan 2022-08-11 16:55:00 2022-08-11 18:45:00       U2 5186
# 141        Istanbul 2022-08-11 16:10:00 2022-08-11 18:00:00       TK 1723
#
#     terminal                airline         aircraft  ICAO IATA
# 0          1                Finnair      Airbus A320  EFHK  HEL
# 1          1             Air Baltic       Fokker 100  EVRA  RIX
# 2          1  Norwegian Air Shuttle   Boeing 737-800  ENGM  OSL
# 3          0                Ryanair   Boeing 737-800  LHBP  BUD
# 4          0                Ryanair   Boeing 737-800  LIPH  TSF
# ..       ...                    ...              ...   ...  ...
# 137        0                Pegasus      Airbus A320  LTAI  AYT
# 138        0                Pegasus   Boeing 737-800  LTFJ  SAW
# 139        1                easyJet      Airbus A320  LGKR  CFU
# 140        1                easyJet      Airbus A319  LIML  LIN
# 141        1                Turkish  Airbus A330-200  LTFM  IST
#
# [141 rows x 9 columns]

# %%
df_arrivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 0 to 141
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   departure_from  141 non-null    object
#  1   departure_time  141 non-null    datetime64[ns]
#  2   arrival_time    141 non-null    datetime64[ns]
#  3   flight_number   141 non-null    object
#  4   terminal        141 non-null    object
#  5   airline         141 non-null    object
#  6   aircraft        141 non-null    object
#  7   ICAO            141 non-null    object
#  8   IATA            141 non-null    object
# dtypes: datetime64[ns](2), object(7)
# memory usage: 11.0+ KB

# %% [markdown]
# # Open Weather

# %% [markdown]
# Weather is a huge factor when it comes to scooter usage. On very cold days and, especially, on rainy days, hardly anyone wants to use a scooter.
#
# Thankfully, there is an API that provides free weather forecasts: OpenWeather.
# Obviously, city and API_key are variables that you will have already defined. Once you’ve made this API call, you’ll be able to explore the received information using the requests library and pandas.
#
# The goal is to automate the collection of weather data for multiple cities.
#
# Explore the data received from the API. What’s useful? What’s not?
# Extract the information you see as useful and make a DataFrame from it
# Consolidate the steps you took to make the DataFrame into a single function. The function should output a DataFrame with the weather of multiple cities, when given a list of cities as an input.
# You should be able to use this function to get the weather data for the cities you web scraped yesterday

# %%
city="Berlin"
response_1 = requests.get('http://api.openweathermap.org/data/2.5/forecast?q='+city+'&appid='+owmkey+'&units=metric"')
response_berlin = response_1.json() #formats the scraped data into JSON format
response_berlin #berlin weather forecasts for 5 days every 3 hours as JSON
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1660132800,
#    'main': {'temp': 298.3,
#     'feels_like': 297.97,
#     'temp_min': 298.3,
#     'temp_max': 300.61,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1021,
#     'humidity': 42,
#     'temp_kf': -2.31},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 1.62, 'deg': 29, 'gust': 1.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-10 12:00:00'},
#   {'dt': 1660143600,
#    'main': {'temp': 300.05,
#     'feels_like': 299.63,
#     'temp_min': 300.05,
#     'temp_max': 301.5,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1019,
#     'humidity': 33,
#     'temp_kf': -1.45},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 1.63, 'deg': 25, 'gust': 2.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-10 15:00:00'},
#   {'dt': 1660154400,
#    'main': {'temp': 298.84,
#     'feels_like': 298.33,
#     'temp_min': 298.84,
#     'temp_max': 298.84,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1018,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 2.83, 'deg': 20, 'gust': 4.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-10 18:00:00'},
#   {'dt': 1660165200,
#    'main': {'temp': 293.89,
#     'feels_like': 293.12,
#     'temp_min': 293.89,
#     'temp_max': 293.89,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1019,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.38, 'deg': 43, 'gust': 10.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-10 21:00:00'},
#   {'dt': 1660176000,
#    'main': {'temp': 291.56,
#     'feels_like': 290.74,
#     'temp_min': 291.56,
#     'temp_max': 291.56,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1019,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.82, 'deg': 64, 'gust': 6.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-11 00:00:00'},
#   {'dt': 1660186800,
#    'main': {'temp': 290.56,
#     'feels_like': 289.64,
#     'temp_min': 290.56,
#     'temp_max': 290.56,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1018,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.79, 'deg': 56, 'gust': 2.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-11 03:00:00'},
#   {'dt': 1660197600,
#    'main': {'temp': 293.28,
#     'feels_like': 292.47,
#     'temp_min': 293.28,
#     'temp_max': 293.28,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1019,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.12, 'deg': 59, 'gust': 2.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-11 06:00:00'},
#   {'dt': 1660208400,
#    'main': {'temp': 299.37,
#     'feels_like': 299.37,
#     'temp_min': 299.37,
#     'temp_max': 299.37,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1019,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.41, 'deg': 62, 'gust': 2.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-11 09:00:00'},
#   {'dt': 1660219200,
#    'main': {'temp': 302.65,
#     'feels_like': 301.05,
#     'temp_min': 302.65,
#     'temp_max': 302.65,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1017,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 2.27, 'deg': 61, 'gust': 3.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-11 12:00:00'},
#   {'dt': 1660230000,
#    'main': {'temp': 303.5,
#     'feels_like': 301.64,
#     'temp_min': 303.5,
#     'temp_max': 303.5,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 19,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 2.89, 'deg': 55, 'gust': 3.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-11 15:00:00'},
#   {'dt': 1660240800,
#    'main': {'temp': 300.29,
#     'feels_like': 299.48,
#     'temp_min': 300.29,
#     'temp_max': 300.29,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1015,
#     'humidity': 25,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 28},
#    'wind': {'speed': 2.6, 'deg': 84, 'gust': 5.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-11 18:00:00'},
#   {'dt': 1660251600,
#    'main': {'temp': 295.23,
#     'feels_like': 294.62,
#     'temp_min': 295.23,
#     'temp_max': 295.23,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 3.49, 'deg': 53, 'gust': 8.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-11 21:00:00'},
#   {'dt': 1660262400,
#    'main': {'temp': 292.93,
#     'feels_like': 292.14,
#     'temp_min': 292.93,
#     'temp_max': 292.93,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 1.75, 'deg': 107, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-12 00:00:00'},
#   {'dt': 1660273200,
#    'main': {'temp': 291.74,
#     'feels_like': 290.8,
#     'temp_min': 291.74,
#     'temp_max': 291.74,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 1.21, 'deg': 146, 'gust': 1.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-12 03:00:00'},
#   {'dt': 1660284000,
#    'main': {'temp': 294.58,
#     'feels_like': 293.8,
#     'temp_min': 294.58,
#     'temp_max': 294.58,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1017,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.83, 'deg': 115, 'gust': 2.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-12 06:00:00'},
#   {'dt': 1660294800,
#    'main': {'temp': 300.05,
#     'feels_like': 299.43,
#     'temp_min': 300.05,
#     'temp_max': 300.05,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1016,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.45, 'deg': 96, 'gust': 4.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-12 09:00:00'},
#   {'dt': 1660305600,
#    'main': {'temp': 302.73,
#     'feels_like': 301.2,
#     'temp_min': 302.73,
#     'temp_max': 302.73,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.15, 'deg': 89, 'gust': 4.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-12 12:00:00'},
#   {'dt': 1660316400,
#    'main': {'temp': 303.65,
#     'feels_like': 301.92,
#     'temp_min': 303.65,
#     'temp_max': 303.65,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 3.87, 'deg': 91, 'gust': 5.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-12 15:00:00'},
#   {'dt': 1660327200,
#    'main': {'temp': 300.85,
#     'feels_like': 300.12,
#     'temp_min': 300.85,
#     'temp_max': 300.85,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 2.97, 'deg': 125, 'gust': 5.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-12 18:00:00'},
#   {'dt': 1660338000,
#    'main': {'temp': 297.53,
#     'feels_like': 297.09,
#     'temp_min': 297.53,
#     'temp_max': 297.53,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1014,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 1.08, 'deg': 52, 'gust': 1.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-12 21:00:00'},
#   {'dt': 1660348800,
#    'main': {'temp': 296,
#     'feels_like': 295.52,
#     'temp_min': 296,
#     'temp_max': 296,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 1.08, 'deg': 22, 'gust': 1.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-13 00:00:00'},
#   {'dt': 1660359600,
#    'main': {'temp': 294.23,
#     'feels_like': 293.73,
#     'temp_min': 294.23,
#     'temp_max': 294.23,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 1.05, 'deg': 98, 'gust': 1.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-13 03:00:00'},
#   {'dt': 1660370400,
#    'main': {'temp': 295.41,
#     'feels_like': 295.08,
#     'temp_min': 295.41,
#     'temp_max': 295.41,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 42},
#    'wind': {'speed': 1.59, 'deg': 131, 'gust': 2.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-13 06:00:00'},
#   {'dt': 1660381200,
#    'main': {'temp': 301.21,
#     'feels_like': 300.73,
#     'temp_min': 301.21,
#     'temp_max': 301.21,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1013,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 1, 'deg': 134, 'gust': 2.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-13 09:00:00'},
#   {'dt': 1660392000,
#    'main': {'temp': 304.12,
#     'feels_like': 302.85,
#     'temp_min': 304.12,
#     'temp_max': 304.12,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1012,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 0.7, 'deg': 120, 'gust': 2.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-13 12:00:00'},
#   {'dt': 1660402800,
#    'main': {'temp': 302.67,
#     'feels_like': 301.84,
#     'temp_min': 302.67,
#     'temp_max': 302.67,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 2.17, 'deg': 22, 'gust': 2.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-13 15:00:00'},
#   {'dt': 1660413600,
#    'main': {'temp': 300.57,
#     'feels_like': 300.57,
#     'temp_min': 300.57,
#     'temp_max': 300.57,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.25, 'deg': 42, 'gust': 5.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-13 18:00:00'},
#   {'dt': 1660424400,
#    'main': {'temp': 297.19,
#     'feels_like': 297.22,
#     'temp_min': 297.19,
#     'temp_max': 297.19,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1011,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 2.6, 'deg': 38, 'gust': 5.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-13 21:00:00'},
#   {'dt': 1660435200,
#    'main': {'temp': 294.57,
#     'feels_like': 294.62,
#     'temp_min': 294.57,
#     'temp_max': 294.57,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 28},
#    'wind': {'speed': 2.56, 'deg': 50, 'gust': 4.66},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-14 00:00:00'},
#   {'dt': 1660446000,
#    'main': {'temp': 293.37,
#     'feels_like': 293.46,
#     'temp_min': 293.37,
#     'temp_max': 293.37,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.77, 'deg': 36, 'gust': 2.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-14 03:00:00'},
#   {'dt': 1660456800,
#    'main': {'temp': 295.56,
#     'feels_like': 295.66,
#     'temp_min': 295.56,
#     'temp_max': 295.56,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.85, 'deg': 20, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-14 06:00:00'},
#   {'dt': 1660467600,
#    'main': {'temp': 300.64,
#     'feels_like': 300.77,
#     'temp_min': 300.64,
#     'temp_max': 300.64,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.61, 'deg': 43, 'gust': 3.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-14 09:00:00'},
#   {'dt': 1660478400,
#    'main': {'temp': 304.04,
#     'feels_like': 302.96,
#     'temp_min': 304.04,
#     'temp_max': 304.04,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1007,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 3.28, 'deg': 26, 'gust': 3.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-14 12:00:00'},
#   {'dt': 1660489200,
#    'main': {'temp': 303.02,
#     'feels_like': 302.37,
#     'temp_min': 303.02,
#     'temp_max': 303.02,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 5.6, 'deg': 56, 'gust': 5.21},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-14 15:00:00'},
#   {'dt': 1660500000,
#    'main': {'temp': 299.91,
#     'feels_like': 300.29,
#     'temp_min': 299.91,
#     'temp_max': 299.91,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 3.48, 'deg': 68, 'gust': 5.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-14 18:00:00'},
#   {'dt': 1660510800,
#    'main': {'temp': 296.1,
#     'feels_like': 296.15,
#     'temp_min': 296.1,
#     'temp_max': 296.1,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1006,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 3.06, 'deg': 61, 'gust': 5.84},
#    'visibility': 10000,
#    'pop': 0.35,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-14 21:00:00'},
#   {'dt': 1660521600,
#    'main': {'temp': 294.75,
#     'feels_like': 294.82,
#     'temp_min': 294.75,
#     'temp_max': 294.75,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 16},
#    'wind': {'speed': 2.29, 'deg': 84, 'gust': 3.99},
#    'visibility': 10000,
#    'pop': 0.21,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-15 00:00:00'},
#   {'dt': 1660532400,
#    'main': {'temp': 293.81,
#     'feels_like': 293.89,
#     'temp_min': 293.81,
#     'temp_max': 293.81,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 2.37, 'deg': 62, 'gust': 4.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2022-08-15 03:00:00'},
#   {'dt': 1660543200,
#    'main': {'temp': 295.66,
#     'feels_like': 295.72,
#     'temp_min': 295.66,
#     'temp_max': 295.66,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 54},
#    'wind': {'speed': 2.89, 'deg': 76, 'gust': 4.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-15 06:00:00'},
#   {'dt': 1660554000,
#    'main': {'temp': 300.58,
#     'feels_like': 300.78,
#     'temp_min': 300.58,
#     'temp_max': 300.58,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.39, 'deg': 92, 'gust': 2.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2022-08-15 09:00:00'}],
#  'city': {'id': 2950159,
#   'name': 'Berlin',
#   'coord': {'lat': 52.5244, 'lon': 13.4105},
#   'country': 'DE',
#   'population': 1000000,
#   'timezone': 7200,
#   'sunrise': 1660102819,
#   'sunset': 1660156997}}

# %%
response_berlin["list"][6]["weather"][0]["description"]
# Out:
# 'few clouds'

# %%
temps_berlin = []
for i in response_berlin["list"]:
    temps_dict={}
    temps_dict["Weather"]=i["weather"][0]["description"]
    temps_dict['Temparature'] = i['main']["temp"]
    temps_dict['Feels like'] = i['main']["feels_like"]
    temps_dict['Humidity'] = i['main']["humidity"]
    temps_dict["Timestamp"]= i["dt_txt"]
    temps_berlin.append(temps_dict)
    df_ber_temp=pd.DataFrame(temps_berlin)

# %%
df_ber_temp
# Out:
#              Weather  Temparature  Feels like  Humidity            Timestamp
# 0   scattered clouds       298.30      297.97        42  2022-08-10 12:00:00
# 1   scattered clouds       300.05      299.63        33  2022-08-10 15:00:00
# 2   scattered clouds       298.84      298.33        33  2022-08-10 18:00:00
# 3          clear sky       293.89      293.12        42  2022-08-10 21:00:00
# 4          clear sky       291.56      290.74        49  2022-08-11 00:00:00
# 5          clear sky       290.56      289.64        49  2022-08-11 03:00:00
# 6         few clouds       293.28      292.47        43  2022-08-11 06:00:00
# 7         few clouds       299.37      299.37        30  2022-08-11 09:00:00
# 8         few clouds       302.65      301.05        22  2022-08-11 12:00:00
# 9   scattered clouds       303.50      301.64        19  2022-08-11 15:00:00
# 10  scattered clouds       300.29      299.48        25  2022-08-11 18:00:00
# 11     broken clouds       295.23      294.62        43  2022-08-11 21:00:00
# 12  scattered clouds       292.93      292.14        45  2022-08-12 00:00:00
# 13         clear sky       291.74      290.80        44  2022-08-12 03:00:00
# 14         clear sky       294.58      293.80        39  2022-08-12 06:00:00
# 15         clear sky       300.05      299.43        28  2022-08-12 09:00:00
# 16         clear sky       302.73      301.20        24  2022-08-12 12:00:00
# 17         clear sky       303.65      301.92        23  2022-08-12 15:00:00
# 18        few clouds       300.85      300.12        32  2022-08-12 18:00:00
# 19     broken clouds       297.53      297.09        41  2022-08-12 21:00:00
# 20     broken clouds       296.00      295.52        45  2022-08-13 00:00:00
# 21  scattered clouds       294.23      293.73        51  2022-08-13 03:00:00
# 22  scattered clouds       295.41      295.08        53  2022-08-13 06:00:00
# 23     broken clouds       301.21      300.73        38  2022-08-13 09:00:00
# 24     broken clouds       304.12      302.85        30  2022-08-13 12:00:00
# 25   overcast clouds       302.67      301.84        35  2022-08-13 15:00:00
# 26     broken clouds       300.57      300.57        44  2022-08-13 18:00:00
# 27  scattered clouds       297.19      297.22        60  2022-08-13 21:00:00
# 28  scattered clouds       294.57      294.62        71  2022-08-14 00:00:00
# 29         clear sky       293.37      293.46        77  2022-08-14 03:00:00
# 30         clear sky       295.56      295.66        69  2022-08-14 06:00:00
# 31         clear sky       300.64      300.77        46  2022-08-14 09:00:00
# 32         clear sky       304.04      302.96        32  2022-08-14 12:00:00
# 33  scattered clouds       303.02      302.37        37  2022-08-14 15:00:00
# 34  scattered clouds       299.91      300.29        49  2022-08-14 18:00:00
# 35         clear sky       296.10      296.15        65  2022-08-14 21:00:00
# 36        few clouds       294.75      294.82        71  2022-08-15 00:00:00
# 37  scattered clouds       293.81      293.89        75  2022-08-15 03:00:00
# 38     broken clouds       295.66      295.72        67  2022-08-15 06:00:00
# 39   overcast clouds       300.58      300.78        47  2022-08-15 09:00:00

# %%
def temps(city, country):
    temps_city = []
    response = requests.get(f'http://api.openweathermap.org/data/2.5/forecast/?q='+city+','+country+'&appid='+owmkey+'&units=metric&lang=en')
    response_city = response.json()["list"]
    for i in response_city:
        temps_dict={}
        
        temps_dict["weather"]=i["weather"][0]["description"]
        temps_dict['temparature'] = i['main']["temp"]
        temps_dict['feels_like'] = i['main']["feels_like"]
        temps_dict['humidity'] = i['main']["humidity"]
        temps_dict["timestamp"]= i["dt_txt"]
        temps_dict['windspeed']=i["wind"]["speed"]
        temps_dict['municipality_iso_country']=city+","+country
        #temps_dict["municipality_iso_country"]=np.where(city cities["city_ascii"]==,cities["municipality_iso_country"], "AAA" )
        temps_city.append(temps_dict)
        df_city_temp=pd.DataFrame(temps_city)
        #city_forecast=df_city_temp.merge(cities, how="left", left_on="city", right_on="city_ascii"   
        df_city_temp["timestamp"]=pd.to_datetime(df_city_temp["timestamp"])
    return df_city_temp

# %%
df_temps_in_berlin=pd.DataFrame(temps_berlin)
df_temps_in_berlin
# Out:
#              Weather  Temparature  Feels like  Humidity            Timestamp
# 0   scattered clouds       298.30      297.97        42  2022-08-10 12:00:00
# 1   scattered clouds       300.05      299.63        33  2022-08-10 15:00:00
# 2   scattered clouds       298.84      298.33        33  2022-08-10 18:00:00
# 3          clear sky       293.89      293.12        42  2022-08-10 21:00:00
# 4          clear sky       291.56      290.74        49  2022-08-11 00:00:00
# 5          clear sky       290.56      289.64        49  2022-08-11 03:00:00
# 6         few clouds       293.28      292.47        43  2022-08-11 06:00:00
# 7         few clouds       299.37      299.37        30  2022-08-11 09:00:00
# 8         few clouds       302.65      301.05        22  2022-08-11 12:00:00
# 9   scattered clouds       303.50      301.64        19  2022-08-11 15:00:00
# 10  scattered clouds       300.29      299.48        25  2022-08-11 18:00:00
# 11     broken clouds       295.23      294.62        43  2022-08-11 21:00:00
# 12  scattered clouds       292.93      292.14        45  2022-08-12 00:00:00
# 13         clear sky       291.74      290.80        44  2022-08-12 03:00:00
# 14         clear sky       294.58      293.80        39  2022-08-12 06:00:00
# 15         clear sky       300.05      299.43        28  2022-08-12 09:00:00
# 16         clear sky       302.73      301.20        24  2022-08-12 12:00:00
# 17         clear sky       303.65      301.92        23  2022-08-12 15:00:00
# 18        few clouds       300.85      300.12        32  2022-08-12 18:00:00
# 19     broken clouds       297.53      297.09        41  2022-08-12 21:00:00
# 20     broken clouds       296.00      295.52        45  2022-08-13 00:00:00
# 21  scattered clouds       294.23      293.73        51  2022-08-13 03:00:00
# 22  scattered clouds       295.41      295.08        53  2022-08-13 06:00:00
# 23     broken clouds       301.21      300.73        38  2022-08-13 09:00:00
# 24     broken clouds       304.12      302.85        30  2022-08-13 12:00:00
# 25   overcast clouds       302.67      301.84        35  2022-08-13 15:00:00
# 26     broken clouds       300.57      300.57        44  2022-08-13 18:00:00
# 27  scattered clouds       297.19      297.22        60  2022-08-13 21:00:00
# 28  scattered clouds       294.57      294.62        71  2022-08-14 00:00:00
# 29         clear sky       293.37      293.46        77  2022-08-14 03:00:00
# 30         clear sky       295.56      295.66        69  2022-08-14 06:00:00
# 31         clear sky       300.64      300.77        46  2022-08-14 09:00:00
# 32         clear sky       304.04      302.96        32  2022-08-14 12:00:00
# 33  scattered clouds       303.02      302.37        37  2022-08-14 15:00:00
# 34  scattered clouds       299.91      300.29        49  2022-08-14 18:00:00
# 35         clear sky       296.10      296.15        65  2022-08-14 21:00:00
# 36        few clouds       294.75      294.82        71  2022-08-15 00:00:00
# 37  scattered clouds       293.81      293.89        75  2022-08-15 03:00:00
# 38     broken clouds       295.66      295.72        67  2022-08-15 06:00:00
# 39   overcast clouds       300.58      300.78        47  2022-08-15 09:00:00

# %% [markdown]
# # Airport Data

# %% [markdown]
# To get information about all airports we simply load a csv with all airports, found here(https://ourairports.com/data/), into this notebook. Then we filter and adding all columns and rows we need.

# %%
#filtered_df = df.query( '"Country Name" == ["brazil","poland","russia","countrydummy","usa"]' )

airports_cities = (
pd.read_csv('airports.csv')
    .query('type == ["large_airport","medium_airport"]')
    .filter(['name','type','latitude_deg','longitude_deg','iso_country','iso_region','municipality','gps_code','iata_code'])
    .rename(columns={'gps_code':'icao_code'})
    .assign(municipality_iso_country = lambda x: x['municipality'] + ',' + x['iso_country'])
)
airports_cities.head()
airports_cities=airports_cities.drop_duplicates(subset="icao_code")

# %%
airports_cities
# Out:
#                                          name            type  latitude_deg  \
# 6401                  Aleknagik / New Airport  medium_airport     59.282600
# 10856      Khost International Airport (U.C.)  medium_airport     33.284605
# 10890           Honiara International Airport   large_airport     -9.428000
# 10895                           Munda Airport  medium_airport     -8.327970
# 10917                        Hongyuan Airport  medium_airport     32.531540
# ...                                       ...             ...           ...
# 68322               Tonghua Sanyuanpu Airport  medium_airport     42.253889
# 68323  Shenyang Taoxian International Airport   large_airport     41.639801
# 68325             Yanji Chaoyangchuan Airport  medium_airport     42.882801
# 68326                   Yingkou Lanqi Airport  medium_airport     40.542524
# 68327                 Shenyang Dongta Airport  medium_airport     41.784401
#
#        longitude_deg iso_country iso_region      municipality icao_code  \
# 6401     -158.617996          US      US-AK         Aleknagik       5A8
# 10856      69.807340          AF     AF-KHO             Khost       NaN
# 10890     160.054993          SB      SB-CT           Honiara      AGGH
# 10895     157.263000          SB      SB-WE             Munda      AGGM
# 10917     102.352240          CN      CN-51               Aba      ZUHY
# ...              ...         ...        ...               ...       ...
# 68322     125.703333          CN      CN-22           Tonghua      ZYTN
# 68323     123.483002          CN      CN-21  Hunnan, Shenyang      ZYTX
# 68325     129.451004          CN      CN-22             Yanji      ZYYJ
# 68326     122.358600          CN      CN-21  Laobian, Yingkou      ZYYK
# 68327     123.496002          CN      CN-21  Dadong, Shenyang      ZYYY
#
#       iata_code municipality_iso_country
# 6401        WKK             Aleknagik,US
# 10856       NaN                 Khost,AF
# 10890       HIR               Honiara,SB
# 10895       MUA                 Munda,SB
# 10917       AHJ                   Aba,CN
# ...         ...                      ...
# 68322       TNH               Tonghua,CN
# 68323       SHE      Hunnan, Shenyang,CN
# 68325       YNJ                 Yanji,CN
# 68326       YKH      Laobian, Yingkou,CN
# 68327       NaN      Dadong, Shenyang,CN
#
# [4932 rows x 10 columns]

# %% [markdown]
# Then we drop all NaNs...

# %%
airports_cities=airports_cities.dropna()

# %% [markdown]
# ... and check if there any other irregularities.

# %%
airports_cities.isna().sum()
# Out:
# name                        0
# type                        0
# latitude_deg                0
# longitude_deg               0
# iso_country                 0
# iso_region                  0
# municipality                0
# icao_code                   0
# iata_code                   0
# municipality_iso_country    0
# dtype: int64

# %% [markdown]
# # Population Data

# %% [markdown]
# To get information about all cities we simply load a csv, provided with additional information, found here(https://www.kaggle.com/datasets/juanmah/world-cities), into this notebook. Then we filter and adding all columns we need.

# %%
cities = (
pd.read_csv('worldcities.csv')
)

# %% [markdown]
# Doing some data manipulation, in order to make it consistent with the data frame 'airport_cities'.

# %%
cities.at[1002,'city_ascii']='Frankfurt-am-Main'
cities.query("city_ascii=='Frankfurt-am-Main'")
# Out:
#            city         city_ascii      lat     lng  country iso2 iso3  \
# 1002  Frankfurt  Frankfurt-am-Main  50.1136  8.6797  Germany   DE  DEU
#
#      admin_name capital  population          id
# 1002      Hesse   minor    764104.0  1276054552

# %% [markdown]
# Creating this column, in order to have relation to 'airport_cities'.

# %%
cities["municipality_iso_country"]=cities["city_ascii"]+","+cities["iso2"]
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42905 entries, 0 to 42904
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   city                      42905 non-null  object
#  1   city_ascii                42905 non-null  object
#  2   lat                       42905 non-null  float64
#  3   lng                       42905 non-null  float64
#  4   country                   42905 non-null  object
#  5   iso2                      42873 non-null  object
#  6   iso3                      42905 non-null  object
#  7   admin_name                42810 non-null  object
#  8   capital                   9812 non-null   object
#  9   population                42180 non-null  float64
#  10  id                        42905 non-null  int64
#  11  municipality_iso_country  42873 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 3.9+ MB

# %% [markdown]
# Removing rows with irregular data, in order to have consistent data.

# %%
#cities = cities.filter(['city_ascii','iso_country','municipality_iso_country']).drop_duplicates()
cities=cities.dropna()

# %%
cities.isna().sum()
# Out:
# city                        0
# city_ascii                  0
# lat                         0
# lng                         0
# country                     0
# iso2                        0
# iso3                        0
# admin_name                  0
# capital                     0
# population                  0
# id                          0
# municipality_iso_country    0
# dtype: int64

# %% [markdown]
# Filtering all cities with a larger population than 1000 to make this dataset a little bit more compact, since we assume ,that all cities with population smaller than 1000 doesnt have a medium or small airport.

# %%
cities=cities.sort_values("population", ascending= False)


i = cities[(cities.population<1000 )].index
cities=cities.drop(i)
cities
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...            ...          ...      ...       ...          ...  ...  ...
# 9461       Kobarid      Kobarid  46.2471   13.5796     Slovenia   SI  SVN
# 9463   Andrijevica  Andrijevica  42.7339   19.7919   Montenegro   ME  MNE
# 9454      Bosilovo     Bosilovo  41.4406   22.7278    Macedonia   MK  MKD
# 42150      Mazatán      Mazatan  29.0167 -110.1333       Mexico   MX  MEX
# 9164        Soroti       Soroti   1.6833   33.6167       Uganda   UG  UGA
#
#         admin_name  capital  population          id municipality_iso_country
# 0            Tōkyō  primary  39105000.0  1392685764                 Tokyo,JP
# 1          Jakarta  primary  35362000.0  1360771077               Jakarta,ID
# 2            Delhi    admin  31870000.0  1356872604                 Delhi,IN
# 3           Manila  primary  23971000.0  1608618140                Manila,PH
# 4        São Paulo    admin  22495000.0  1076532519             Sao Paulo,BR
# ...            ...      ...         ...         ...                      ...
# 9461       Kobarid    admin      1085.0  1705651680               Kobarid,SI
# 9463   Andrijevica    admin      1073.0  1499379378           Andrijevica,ME
# 9454      Bosilovo    admin      1069.0  1807868218              Bosilovo,MK
# 42150       Sonora    minor      1058.0  1484350756               Mazatan,MX
# 9164        Soroti    admin      1038.0  1800434608                Soroti,UG
#
# [8974 rows x 12 columns]

# %% [markdown]
# Resetting the index, after we our final data manipulation.

# %%
cities=cities.drop_duplicates(subset=['municipality_iso_country'])
cities=cities.reset_index()

# %%
del cities["index"]

# %%
cities
# Out:
#              city   city_ascii      lat       lng      country iso2 iso3  \
# 0           Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1         Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2           Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3          Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4       São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...           ...          ...      ...       ...          ...  ...  ...
# 8904      Kobarid      Kobarid  46.2471   13.5796     Slovenia   SI  SVN
# 8905  Andrijevica  Andrijevica  42.7339   19.7919   Montenegro   ME  MNE
# 8906     Bosilovo     Bosilovo  41.4406   22.7278    Macedonia   MK  MKD
# 8907      Mazatán      Mazatan  29.0167 -110.1333       Mexico   MX  MEX
# 8908       Soroti       Soroti   1.6833   33.6167       Uganda   UG  UGA
#
#        admin_name  capital  population          id municipality_iso_country
# 0           Tōkyō  primary  39105000.0  1392685764                 Tokyo,JP
# 1         Jakarta  primary  35362000.0  1360771077               Jakarta,ID
# 2           Delhi    admin  31870000.0  1356872604                 Delhi,IN
# 3          Manila  primary  23971000.0  1608618140                Manila,PH
# 4       São Paulo    admin  22495000.0  1076532519             Sao Paulo,BR
# ...           ...      ...         ...         ...                      ...
# 8904      Kobarid    admin      1085.0  1705651680               Kobarid,SI
# 8905  Andrijevica    admin      1073.0  1499379378           Andrijevica,ME
# 8906     Bosilovo    admin      1069.0  1807868218              Bosilovo,MK
# 8907       Sonora    minor      1058.0  1484350756               Mazatan,MX
# 8908       Soroti    admin      1038.0  1800434608                Soroti,UG
#
# [8909 rows x 12 columns]

# %% [markdown]
# Renaming some the last two columns

# %%
cities=cities.rename(columns={"lng": "longitude"}, errors="raise")
cities=cities.rename(columns={"lat": "latitude"}, errors="raise")

# %%
cities.query("municipality_iso_country=='Berlin,DE'")
# Out:
#        city city_ascii  latitude  longitude  country iso2 iso3 admin_name  \
# 152  Berlin     Berlin   52.5167    13.3833  Germany   DE  DEU     Berlin
#
#      capital  population          id municipality_iso_country
# 152  primary   3664088.0  1276451290                Berlin,DE

# %% [markdown]
# # Check data

# %%
cities.info()
airports_cities.info()
df_arrivals.info()
df_temps_in_berlin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8909 entries, 0 to 8908
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   city                      8909 non-null   object
#  1   city_ascii                8909 non-null   object
#  2   latitude                  8909 non-null   float64
#  3   longitude                 8909 non-null   float64
#  4   country                   8909 non-null   object
#  5   iso2                      8909 non-null   object
#  6   iso3                      8909 non-null   object
#  7   admin_name                8909 non-null   object
#  8   capital                   8909 non-null   object
#  9   population                8909 non-null   float64
#  10  id                        8909 non-null   int64
#  11  municipality_iso_country  8909 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 835.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4216 entries, 6401 to 68326
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      4216 non-null   object
#  1   type                      4216 non-null   object
#  2   latitude_deg              4216 non-null   float64
#  3   longitude_deg             4216 non-null   float64
#  4   iso_country               4216 non-null   object
#  5   iso_region                4216 non-null   object
#  6   municipality              4216 non-null   object
#  7   icao_code                 4216 non-null   object
#  8   iata_code                 4216 non-null   object
#  9   municipality_iso_country  4216 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 362.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 0 to 141
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   departure_from  141 non-null    object
#  1   departure_time  141 non-null    datetime64[ns]
#  2   arrival_time    141 non-null    datetime64[ns]
#  3   flight_number   141 non-null    object
#  4   terminal        141 non-null    object
#  5   airline         141 non-null    object
#  6   aircraft        141 non-null    object
#  7   ICAO            141 non-null    object
#  8   IATA            141 non-null    object
# dtypes: datetime64[ns](2), object(7)
# memory usage: 11.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Weather      40 non-null     object
#  1   Temparature  40 non-null     float64
#  2   Feels like   40 non-null     float64
#  3   Humidity     40 non-null     int64
#  4   Timestamp    40 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.7+ KB

# %% [markdown]
# We are merging 'airport_cities' and 'cities' in order to detect airport cities, which are not in 'cities' and avoid errors, when we late define the foreign keys.

# %%
airport_cities=airports_cities.merge(cities, left_on="municipality_iso_country", right_on="municipality_iso_country")

# %%
airport_cities.isna().sum()
# Out:
# name                        0
# type                        0
# latitude_deg                0
# longitude_deg               0
# iso_country                 0
# iso_region                  0
# municipality                0
# icao_code                   0
# iata_code                   0
# municipality_iso_country    0
# city                        0
# city_ascii                  0
# latitude                    0
# longitude                   0
# country                     0
# iso2                        0
# iso3                        0
# admin_name                  0
# capital                     0
# population                  0
# id                          0
# dtype: int64

# %% [markdown]
# Deleting unnecessary columns

# %%
airport_cities

del airport_cities["city_ascii"]
del airport_cities["country"]
del airport_cities["iso2"]
del airport_cities["iso3"]
del airport_cities["id"]
del airport_cities["population"]
del airport_cities["city"]
del airport_cities["admin_name"]
del airport_cities["capital"]

# %%
#del airport_cities["city"]
airport_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 0 to 1340
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      1341 non-null   object
#  1   type                      1341 non-null   object
#  2   latitude_deg              1341 non-null   float64
#  3   longitude_deg             1341 non-null   float64
#  4   iso_country               1341 non-null   object
#  5   iso_region                1341 non-null   object
#  6   municipality              1341 non-null   object
#  7   icao_code                 1341 non-null   object
#  8   iata_code                 1341 non-null   object
#  9   municipality_iso_country  1341 non-null   object
#  10  latitude                  1341 non-null   float64
#  11  longitude                 1341 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 136.2+ KB

# %% [markdown]
# We are merging 'df_arrivals' and 'airport_cities' in order to detect airports , which are not in 'airport_cities' and avoid errors, when we late define the foreign keys.

# %%
df_arrivals.merge(airports_cities, how="left", left_on="ICAO", right_on="icao_code").isna().sum()
# Out:
# departure_from              0
# departure_time              0
# arrival_time                0
# flight_number               0
# terminal                    0
# airline                     0
# aircraft                    0
# ICAO                        0
# IATA                        0
# name                        0
# type                        0
# latitude_deg                0
# longitude_deg               0
# iso_country                 0
# iso_region                  0
# municipality                0
# icao_code                   0
# iata_code                   0
# municipality_iso_country    0
# dtype: int64

# %%
df_arrivals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 0 to 141
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   departure_from  141 non-null    object
#  1   departure_time  141 non-null    datetime64[ns]
#  2   arrival_time    141 non-null    datetime64[ns]
#  3   flight_number   141 non-null    object
#  4   terminal        141 non-null    object
#  5   airline         141 non-null    object
#  6   aircraft        141 non-null    object
#  7   ICAO            141 non-null    object
#  8   IATA            141 non-null    object
# dtypes: datetime64[ns](2), object(7)
# memory usage: 11.0+ KB

# %% [markdown]
# # SQL

# %% [markdown]
# We are now trying to establish a local MySQL Connection...

# %%
schema="gans"
host="127.0.0.1"
user="root"
password=loc_pw
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ... and after creating the database and tables in MySQL we fill up those tables with the data from the data frames

# %%
cities.to_sql('cities', con=con, if_exists='append', index=False)
# Out:
# 8909

# %%
airport_cities.to_sql('airport_cities', if_exists='append', con=con, index=False)
# Out:
# 1341

# %%
df_arrivals.to_sql('arrivals', if_exists='append', con=con, index=False)

# %%
df_temps_in_berlin.to_sql('weather', if_exists='append', con=con, index=False)

# %% [markdown]
# # Connecting to Amazon RDS

# %% [markdown]
# Now after this connection succedded, we are now trying to establish a MySQL Connection to the Relational Database created in AWS via RDS.

# %%
aaa=temps("Hannover", "DE")
aaa.info()

# %%
schema="gans"
host=rds_host
user="admin" 
password=rds_pw
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
aaa.to_sql('weather', if_exists='append', con=con, index=False)

# %%
cities.to_sql('cities', con=con, if_exists='append', index=False)
# Out:
# 8909

# %%
airport_cities.to_sql('airport_cities', if_exists='append', con=con, index=False)
# Out:
# 1341

# %%
df_arrivals.to_sql('arrivals', if_exists='append', con=con, index=False)

# %% [markdown]
# After this is finished succeded as well, we can automatically update the data from 'df_ber_temp' and 'df_arrivals'.
#
# To do this, we first set up lambda functions via AWS to make the API calls.
#
# Then, we set up a timed trigger for these functions that calls these functions at timed intervals.(The Lambda functions are in 'Lambda F1.py' and 'Lambda F2.py', but pretty useless out the this AWS environment)
